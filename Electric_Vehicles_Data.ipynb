# %% [markdown]
# # ELECTRIC VEHICLES DATA

# %%
+
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset=pd.read_excel('New Project.xlsx')

# %%
dataset
# Out:
#      VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0    5YJ3E1EB4L     Yakima        Yakima    WA        98908        2020
# 1    5YJ3E1EA7K  San Diego     San Diego    CA        92101        2019
# 2    7JRBR0FL9M       Lane        Eugene    OR        97404        2021
# 3    5YJXCBE21K     Yakima        Yakima    WA        98908        2019
# 4    5UXKT0C5XH  Snohomish       Bothell    WA        98021        2017
# ..          ...        ...           ...   ...          ...         ...
# 994  7SAYGDEF3N       King  Maple Valley    WA        98038        2022
# 995  1N4AZ1BPXL     Kitsap       Poulsbo    WA        98370        2020
# 996  KM8K23AG9K      Clark     Vancouver    WA        98683        2019
# 997  1G1RB6E49C      Clark         Camas    WA        98607        2012
# 998  5YJSA1E25K     Pierce    South Hill    WA        98373        2019
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# # Data PreProcessing

# %%
dataset.isnull()
# Out:
#      VIN (1-10)  County   City  State  Postal Code  Model Year   Make  Model  \
# 0         False   False  False  False        False       False  False  False
# 1         False   False  False  False        False       False  False  False
# 2         False   False  False  False        False       False  False  False
# 3         False   False  False  False        False       False  False  False
# 4         False   False  False  False        False       False  False  False
# ..          ...     ...    ...    ...          ...         ...    ...    ...
# 994       False   False  False  False        False       False  False  False
# 995       False   False  False  False        False       False  False  False
# 996       False   False  False  False        False       False  False  False
# 997       False   False  False  False        False       False  False  False
# 998       False   False  False  False        False       False  False  False
#
# ...

# %%
dataset.fillna(0)
# Out:
#      VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0    5YJ3E1EB4L     Yakima        Yakima    WA        98908        2020
# 1    5YJ3E1EA7K  San Diego     San Diego    CA        92101        2019
# 2    7JRBR0FL9M       Lane        Eugene    OR        97404        2021
# 3    5YJXCBE21K     Yakima        Yakima    WA        98908        2019
# 4    5UXKT0C5XH  Snohomish       Bothell    WA        98021        2017
# ..          ...        ...           ...   ...          ...         ...
# 994  7SAYGDEF3N       King  Maple Valley    WA        98038        2022
# 995  1N4AZ1BPXL     Kitsap       Poulsbo    WA        98370        2020
# 996  KM8K23AG9K      Clark     Vancouver    WA        98683        2019
# 997  1G1RB6E49C      Clark         Camas    WA        98607        2012
# 998  5YJSA1E25K     Pierce    South Hill    WA        98373        2019
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                1
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 6
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     9
# 2020 Census Tract                                    0
# dtype: int64

# %%
dataset['Model'] = dataset['Model'].fillna(0)

# %%
dataset['Model']
# Out:
# 0      MODEL 3
# 1      MODEL 3
# 2          S60
# 3      MODEL X
# 4           X5
#         ...
# 994    MODEL Y
# 995       LEAF
# 996       KONA
# 997       VOLT
# 998    MODEL S
# Name: Model, Length: 999, dtype: object

# %%
dataset.isnull()
# Out:
#      VIN (1-10)  County   City  State  Postal Code  Model Year   Make  Model  \
# 0         False   False  False  False        False       False  False  False
# 1         False   False  False  False        False       False  False  False
# 2         False   False  False  False        False       False  False  False
# 3         False   False  False  False        False       False  False  False
# 4         False   False  False  False        False       False  False  False
# ..          ...     ...    ...    ...          ...         ...    ...    ...
# 994       False   False  False  False        False       False  False  False
# 995       False   False  False  False        False       False  False  False
# 996       False   False  False  False        False       False  False  False
# 997       False   False  False  False        False       False  False  False
# 998       False   False  False  False        False       False  False  False
#
# ...

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 6
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     9
# 2020 Census Tract                                    0
# dtype: int64

# %%
dataset['Electric Utility'] = dataset['Electric Utility'].fillna(0)

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 6
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
dataset['Base MSRP']=dataset['Base MSRP'].fillna(0)

# %%
dataset['Base MSRP']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 994    0
# 995    0
# 996    0
# 997    0
# 998    0
# Name: Base MSRP, Length: 999, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 6
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
dataset['Legislative District']=dataset['Legislative District'].fillna(0)

# %%
dataset['Legislative District']
# Out:
# 0      14.0
# 1       0.0
# 2       0.0
# 3      14.0
# 4       1.0
#        ...
# 994     5.0
# 995    23.0
# 996    18.0
# 997    18.0
# 998    25.0
# Name: Legislative District, Length: 999, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# ...

# %%
dataset.isnull()
# Out:
#      VIN (1-10)  County   City  State  Postal Code  Model Year   Make  Model  \
# 0         False   False  False  False        False       False  False  False
# 1         False   False  False  False        False       False  False  False
# 2         False   False  False  False        False       False  False  False
# 3         False   False  False  False        False       False  False  False
# 4         False   False  False  False        False       False  False  False
# ..          ...     ...    ...    ...          ...         ...    ...    ...
# 994       False   False  False  False        False       False  False  False
# 995       False   False  False  False        False       False  False  False
# 996       False   False  False  False        False       False  False  False
# 997       False   False  False  False        False       False  False  False
# 998       False   False  False  False        False       False  False  False
#
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.barplot(x='Electric Range',y='Make',data=dataset.head(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Make'>

# %%
sns.barplot(x='Electric Range',y='Model',data=dataset.head(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Model'>

# %%
sns.jointplot(x='Electric Range',y='Make',data=dataset.head(100))

# %%
sns.pairplot(dataset,hue='Make')

# %%
sns.barplot(x='Electric Range',y='Make',data=dataset.tail(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Make'>

# %%
sns.barplot(x='Electric Range',y='Model',data = dataset.tail(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Model'>

# %%
fig = plt.subplots (figsize = (12, 12))
sns.heatmap(dataset.corr (), square = True, cbar = True, annot = True, cmap="GnBu", annot_kws = {'size': 8})
plt.title('Correlations between Attributes')
plt.show ()

# %%
sns.boxplot(x="Electric Range", y="Make", data=dataset.head(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Make'>

# %%
sns.boxplot(x='Electric Range',y='Model',data=dataset.head(100))
# Out:
# <AxesSubplot:xlabel='Electric Range', ylabel='Model'>

# %%
plt.figure(figsize=(35,10))
dataset['Make'].hist(alpha=1.0,color='blue',label='Make')
plt.legend()
plt.xlabel('High Sales')
# Out:
# Text(0.5, 0, 'High Sales')

# %%
plt.figure(figsize=(35,10))
dataset['County'].hist(alpha=1.0,color='blue',label='Model')
plt.legend()
plt.xlabel('High Sales')
# Out:
# Text(0.5, 0, 'High Sales')

# %%
sns.distplot(x=dataset['Legislative District'],bins=10)
# Out:
# C:\Users\nutha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
